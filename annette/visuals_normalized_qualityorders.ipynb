# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
ls -a
# Out:
# ./
# ../
# .DS_Store
# .RData
# .Rhistory
# .ipynb_checkpoints/
# PlottingFunctions.py
# Untitled.ipynb
# Untitled1.ipynb
# __pycache__/
# backup_pythonrtranslate.R
# clean_quality_inr.csv
# kmeans_quality.ipynb
# kmeans_users.ipynb
# new_df.csv
# new_rf_order_quality_df.csv
# nobuckets_order_quality_df.csv
# order_train.csv
# prelimEDA.ipynb
# product_df.csv
# python_to_R_translate.R
# quality_df.csv
# quality_featureimportance_randomforest_pre_cleaning.R
# randomforest_featureimportance_qualityorder.ipynb
# randomforest_featureimportance_userorder.ipynb
# rf_order_quality_df.csv
# user_df.csv
# user_featureimportance_randomforest.R
# users_and_orders.csv
# users_and_orders2.csv
# visuals_qualityorder.ipynb
# visuals_qualityorder_nobuckets.ipynb
# visuals_userorder.ipynb
# wishlist.R

# %%
# reading in the data

new_df = pd.read_csv('new_df.csv')
print('size', new_df.shape)
# Out:
# size (129972, 17)

# %%
new_df.columns
# Out:
# Index(['user_id', 'av_date', 'av_appterm', 'av_applimit', 'result',
#        'application_type', 'application_term', 'application_limit', 'op_type',
#        'col_type', 'user_loan_experience', 'user_has_car',
#        'user_social_security', 'qid77', 'spam_score', 'quality',
#        'user_work_period'],
#       dtype='object')

# %%
feat = 'av_date'
data = pd.concat([new_df['result'], new_df[feat]], axis = 1)
f, ax = plt.subplots(figsize = (8,8))
fig = sns.barplot(x=feat, y="result", data = data)

# %%
feat = 'application_type'
data = pd.concat([new_df['result'], new_df[feat]], axis = 1)
f, ax = plt.subplots(figsize = (8,8))
fig = sns.barplot(x=feat, y="result", data = data)

# %%
feat = 'av_appterm'
data = pd.concat([new_df['result'], new_df[feat]], axis = 1)
f, ax = plt.subplots(figsize = (8,8))
fig = sns.barplot(x=feat, y="result", data = data)

# %%
feat = 'av_applimit'
data = pd.concat([new_df['result'], new_df[feat]], axis = 1)
f, ax = plt.subplots(figsize = (8,8))
fig = sns.barplot(x=feat, y="result", data = data)

# %%
feat = 'application_term'
data = pd.concat([new_df['result'], new_df[feat]], axis = 1)
f, ax = plt.subplots(figsize = (8,8))
fig = sns.barplot(x=feat, y="result", data = data)

# %%
feat = 'application_limit'
data = pd.concat([new_df['result'], new_df[feat]], axis = 1)
f, ax = plt.subplots(figsize = (8,8))
fig = sns.barplot(x=feat, y="result", data = data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-22a8195a9b22> in <module>
#       2 data = pd.concat([new_df['result'], new_df[feat]], axis = 1)
#       3 f, ax = plt.subplots(figsize = (8,8))
# ----> 4 fig = sns.barplot(x=feat, y="result", data = data)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3153         ax = plt.gca()
#    3154
# -> 3155     plotter.plot(ax, kwargs)
#    3156     return ax
#    3157
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in plot(self, ax, bar_kws)
#    1667     def plot(self, ax, bar_kws):
#    1668         """Make the plot."""
# -> 1669         self.draw_bars(ax, bar_kws)
#    1670         self.annotate_axes(ax)
#    1671         if self.orient == "h":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in draw_bars(self, ax, kws)
#    1642                                errcolors,
#    1643                                self.errwidth,
# -> 1644                                self.capsize)
#    1645
#    1646         else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in draw_confints(self, ax, at_group, confint, colors, errwidth, capsize, **kws)
#    1587                                                 colors):
#    1588             if self.orient == "v":
# -> 1589                 ax.plot([at, at], [ci_low, ci_high], color=color, **kws)
#    1590                 if capsize is not None:
#    1591                     ax.plot([at - capsize / 2, at + capsize / 2],
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1666         for line in lines:
#    1667             self.add_line(line)
# -> 1668         self.autoscale_view(scalex=scalex, scaley=scaley)
#    1669         return lines
#    1670
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in autoscale_view(self, tight, scalex, scaley)
#    2413                 (self._xmargin and scalex and self._autoscaleXon) or
#    2414                 (self._ymargin and scaley and self._autoscaleYon)):
# -> 2415             stickies = [artist.sticky_edges for artist in self.get_children()]
#    2416             x_stickies = np.array([x for sticky in stickies for x in sticky.x])
#    2417             y_stickies = np.array([y for sticky in stickies for y in sticky.y])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in <listcomp>(.0)
#    2413                 (self._xmargin and scalex and self._autoscaleXon) or
#    2414                 (self._ymargin and scaley and self._autoscaleYon)):
# -> 2415             stickies = [artist.sticky_edges for artist in self.get_children()]
#    2416             x_stickies = np.array([x for sticky in stickies for x in sticky.x])
#    2417             y_stickies = np.array([y for sticky in stickies for y in sticky.y])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in sticky_edges(self)
#    1018         self.stale = True
#    1019
# -> 1020     @property
#    1021     def sticky_edges(self):
#    1022         """
#
# KeyboardInterrupt:

# %%
feat = 'op_type'
data = pd.concat([new_df['result'], new_df[feat]], axis = 1)
f, ax = plt.subplots(figsize = (8,8))
fig = sns.barplot(x=feat, y="result", data = data)

# %%
feat = 'col_type'
data = pd.concat([new_df['result'], new_df[feat]], axis = 1)
f, ax = plt.subplots(figsize = (8,8))
fig = sns.barplot(x=feat, y="result", data = data)

# %%
feat = 'user_loan_experience'
data = pd.concat([new_df['result'], new_df[feat]], axis = 1)
f, ax = plt.subplots(figsize = (8,8))
fig = sns.barplot(x=feat, y="result", data = data)

# %%
feat = 'user_has_car'
data = pd.concat([new_df['result'], new_df[feat]], axis = 1)
f, ax = plt.subplots(figsize = (8,8))
fig = sns.barplot(x=feat, y="result", data = data)

# %%
feat = 'user_social_security'
data = pd.concat([new_df['result'], new_df[feat]], axis = 1)
f, ax = plt.subplots(figsize = (8,8))
fig = sns.barplot(x=feat, y="result", data = data)

# %%
feat = 'qid77'
data = pd.concat([new_df['result'], new_df[feat]], axis = 1)
f, ax = plt.subplots(figsize = (8,8))
fig = sns.barplot(x=feat, y="result", data = data)

# %%
feat = 'spam_score'
data = pd.concat([new_df['result'], new_df[feat]], axis = 1)
f, ax = plt.subplots(figsize = (8,8))
fig = sns.barplot(x=feat, y="result", data = data)

# %%
feat = 'quality'
data = pd.concat([new_df['result'], new_df[feat]], axis = 1)
f, ax = plt.subplots(figsize = (8,8))
fig = sns.barplot(x=feat, y="result", data = data)

# %%
feat = 'user_work_period'
data = pd.concat([new_df['result'], new_df[feat]], axis = 1)
f, ax = plt.subplots(figsize = (8,8))
fig = sns.barplot(x=feat, y="result", data = data)
